# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
headers = ['Country', 'Visitors']

df = pd.read_csv('Test.csv', delimiter=",", names=headers)
x = df['Country']
y = df['Visitors']
print (x)
print (y)
# Out:
# 0         Australia
# 1            Canada
# 2           Germany
# 3    United Kingdom
# 4     United States
# Name: Country, dtype: object
# 0      91
# 1      93
# 2     109
# 3     170
# 4    1343
# Name: Visitors, dtype: int64

# %%
print(df.shape)
print(df.columns)
# Out:
# (5, 2)
# Index(['Country', 'Visitors'], dtype='object')

# %%
print(df.count())
# Out:
# Country     5
# Visitors    5
# dtype: int64

# %%
print(df.min())
print(df.max())
# Out:
# Country     Australia
# Visitors           91
# dtype: object
# Country     United States
# Visitors             1343
# dtype: object

# %%
df.describe() #Resumo estatístico do DataFrame, com quartis, mediana, etc
# Out:
#           Visitors
# count     5.000000
# mean    361.200000
# std     549.780138
# min      91.000000
# 25%      93.000000
# 50%     109.000000
# 75%     170.000000
# max    1343.000000

# %%
df.mean()
# Out:
# Visitors    361.2
# dtype: float64

# %%
plt.bar(x, y)
plt.xlabel('Country')
plt.ylabel('Visitors')
plt.title('September Visitors')
plt.show()

# %%
print(df.apply(lambda x: calcularMedia)
# Out:
#      Country  Visitors
# 0  Australia        91
# 1     Canada        93
# 2    Germany       109
# 3         UK       170
# 4         US      1343

# %%
x = df['Country']
y = df['Visitors']
plt.xlabel('Country')
plt.ylabel('Visitors')
plt.title('September Visitors')
plt.bar(x, y)
plt.show()
# Out:
# 0    Australia
# 1       Canada
# 2      Germany
# 3           UK
# 4           US
# Name: Country, dtype: object

# %%
# Fixing random state for reproducibility
np.random.seed(5)

# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)
