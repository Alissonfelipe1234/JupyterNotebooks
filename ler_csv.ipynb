# %%
import constantes as cnst
import pandas as pd

# %%
dataset_ac = pd.read_csv(cnst.DADOS_ESTADO_AC)
dataset_ac.head()
# Out:
#         id  n_tp_ocorrencia  n_co_municipio_ibge_ocorrencia  n_nu_idade  \
# 0  78304AC                1                         1200104          38
# 1  78305AC                1                         1200104          27
# 2  78306AC                1                         1200104          25
# 3  78307AC                1                         1200104          23
# 4  78308AC                1                         1200104          21
#
#    n_tp_estado_civil  n_tp_escolaridade  n_qt_nascidos_vivos  \
# 0                  1                  4                    0
# 1                  1                  2                    2
# 2                  1                  3                    0
# 3                  2                  3                    2
# 4                  2                  4                    0
#
#    n_qt_nascidos_mortos  n_co_municipio_ibge_residencia  n_tp_gestacao  ...  \
# 0                     0                         1200104              5  ...
# ...

# %%
dataset_es = pd.read_csv(cnst.DADOS_ESTADO_ES)
dataset_es.head()
# Out:
#          id  n_tp_ocorrencia  n_co_municipio_ibge_ocorrencia  n_nu_idade  \
# 0  276890ES                1                         2704302          28
# 1  276891ES                1                         3204559          30
# 2  276892ES                1                         3204559          17
# 3  276893ES                1                         3204559          26
# 4  276894ES                1                         3204559          19
#
#    n_tp_estado_civil  n_tp_escolaridade  n_qt_nascidos_vivos  \
# 0                  2                  4                    1
# 1                  2                  2                    5
# 2                  2                  4                    0
# 3                  2                  3                    2
# 4                  2                  3                    0
#
#    n_qt_nascidos_mortos  n_co_municipio_ibge_residencia  n_tp_gestacao  ...  \
# 0                     1                         3205309              5  ...
# ...

# %%
dataset_rn = pd.read_csv(cnst.DADOS_ESTADO_RN)
dataset_rn.head()
# Out:
#          id  n_tp_ocorrencia  n_co_municipio_ibge_ocorrencia  n_nu_idade  \
# 0  266147RN                1                         2704302          20
# 1  266148RN                1                         2708006          26
# 2  266149RN                1                         2702306          35
# 3  266151RN                1                         2709400          18
# 4  266152RN                2                         2701357          22
#
#    n_tp_estado_civil  n_tp_escolaridade  n_qt_nascidos_vivos  \
# 0                  1                  4                    0
# 1                  2                  5                    1
# 2                  1                  3                    8
# 3                  1                  2                    1
# 4                  1                  1                    2
#
#    n_qt_nascidos_mortos  n_co_municipio_ibge_residencia  n_tp_gestacao  ...  \
# 0                     1                         2414902              5  ...
# ...
